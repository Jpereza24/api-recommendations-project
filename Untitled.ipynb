# %%
import os
from pymongo import MongoClient
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Get Password
password = os.getenv("MONGOURL")
client = MongoClient(password)
db = client['apiproject']
coll = db['chats']

# %%
prueba = list(coll.find())

# %%
# Out:
# [{'_id': ObjectId('5de1632be0f936c551df9a18'),
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': ObjectId('5de1632be0f936c551df9a19'),
#   'idUser': 1,
#   'userName': 'Mike Wazowski',
#   'idMessage': 1,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:16:59',
#   'text': 'Dude!!! 😀️ Did you watch the game last night?'},
#  {'_id': ObjectId('5de1632be0f936c551df9a1a'),
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': ObjectId('5de1632be0f936c551df9a1b'),
#   'idUser': 1,
#   'userName': 'Mike Wazowski',
#   'idMessage': 3,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:18:41',
#   'text': 'Awesome! Boyander scored 3 goals!'},
#  {'_id': ObjectId('5de1632be0f936c551df9a1c'),
#   'idUser': 0,
#   'userName': 'John Wick',
# ...
