# %%
import json
import pandas as pd

# %%
chats = pd.read_json("./chats.json")

# %%
chats
# Out:
#     idUser                userName  idMessage  idChat            datetime  \
# 0        0               John Wick          0       0 2019-10-17 10:15:41
# 1        1           Mike Wazowski          1       0 2019-10-17 10:16:59
# 2        0               John Wick          2       0 2019-10-17 10:17:31
# 3        1           Mike Wazowski          3       0 2019-10-17 10:18:41
# 4        0               John Wick          4       0 2019-10-17 10:19:41
# 5        1           Mike Wazowski          5       0 2019-10-17 10:20:41
# 6        0               John Wick          6       0 2019-10-17 10:21:41
# 7        1           Mike Wazowski          7       0 2019-10-17 10:22:41
# 8        0               John Wick          8       0 2019-10-17 10:23:41
# 9        1           Mike Wazowski          9       0 2019-10-17 10:24:41
# 10       2             Leia Organa         10       1 2019-10-18 10:15:41
# 11       3              Tony Stark         11       1 2019-10-18 10:16:41
# ...

# %%
users = chats.groupby()

# %%
users
# Out:
#                         idUser
# userName
# John Wick                  NaN
# Mike Wazowski              NaN
# John Wick                  NaN
# Mike Wazowski              NaN
# John Wick                  NaN
# Mike Wazowski              NaN
# John Wick                  NaN
# Mike Wazowski              NaN
# John Wick                  NaN
# Mike Wazowski              NaN
# Leia Organa                NaN
# Tony Stark                 NaN
# Leia Organa                NaN
# Tony Stark                 NaN
# Leia Organa                NaN
# Tony Stark                 NaN
# Leia Organa                NaN
# Tony Stark                 NaN
# Leia Organa                NaN
# Tony Stark                 NaN
# Mike Wazowski              NaN
# Ellen Ripley               NaN
# Mike Wazowski              NaN
# Ellen Ripley               NaN
# Mike Wazowski              NaN
# Ellen Ripley               NaN
# Mike Wazowski              NaN
# Ellen Ripley               NaN
# ...
